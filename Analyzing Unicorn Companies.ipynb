# %% [markdown]
# # Analyzing Unicorn Companies

# %% [markdown]
# Did you know that the average return from investing in stocks is 10% per year! But who wants to be average?!
#
# You have been asked to support an investment firm by analyzing trends in high-growth companies. They are interested in understanding which industries are producing the highest valuations and the rate at which new high-value companies are emerging. Providing them with this information gives them a competitive insight as to industry trends and how they should structure their portfolio looking forward.
#
#
#
# You have been given access to their `unicorns` database, which contains the following tables:
#
# `dates`
#
# | Column         | Description                                     |
# |-------------   |------------------------------------------------ |
# | `company_id`   | A unique ID for the company.                    |
# | `date_joined`  | The date that the company became a unicorn.     |
# | `year_founded` | The year that the company was founded.          |
#
# `funding`
#
# | Column           | Description                                  |
# |----------------- |--------------------------------------------- |
# | company_id       | A unique ID for the company.                 |
# | valuation        | Company value in US dollars.                 |
# | funding          | The amount of funding raised in US dollars.  |
# | select_investors | A list of key investors in the company.      |
#
# `industries`
#
# | Column       | Description                                  |
# |------------- |--------------------------------------------- |
# | company_id   | A unique ID for the company.                 |
# | industry     | The industry that the company operates in.   |
#
# `companies`
#
# | Column       | Description                                       |
# |------------- |-------------------------------------------------- |
# | company_id   | A unique ID for the company.                      |
# | company      | The name of the company.                          |
# | city         | The city where the company is headquartered.      |
# | country      | The country where the company is headquartered.   |
# | continent    | The continent where the company is headquartered. |

# %% [markdown]
# ## instructions
#
# Your task is to first identify the three best-performing industries based on the number of new unicorns created over the last three years (2019, 2020, and 2021) combined.
#
# From there, you will write a query to return the industry, the year, the number of companies in these industries that became unicorns each year in 2019, 2020, and 2021, along with the average valuation per industry per year, converted to billions of dollars and rounded to two decimal places!
#
# As the firm is interested in trends for the top-performing industries, your results should be displayed by industry, then year in descending order.
#
# The final output of your query will look like this:
#
# |industry	|year	|num_unicorns	|average_valuation_billions|
# |-----------|-------|---------------|--------------------------|
# |industry1	|2021	|---	        |---                       |
# |industry1	|2020	|---	        |---|
# |industry1	|2019	|---	        |---|
# |industry2	|2021	|---	        |---|
# |industry2	|2020	|---	        |---|
# |industry2	|2019	|---	        |---|
# |industry3	|2021	|---	        |---|
# |industry3	|2020	|---	        |---|
# |industry3	|2019	|---	        |---|
#
# Where industry1, industry2, and industry3 are the three top-performing industries.

# %% [markdown]
# ### Thing to know to run sql in notebook

# %%
# load sql extension to be able to run sql statement in notebook cells
# %load_ext sql

# %% [markdown]
# - Allow only allows for a single statement to be executed
# %sql

# %% [markdown]
# - Allows a block of SQL to be executed.
# %%sql

# %% [markdown]
# ### let's start

# %%
#create sql engine unicorn
#we will use sqlite
from sqlalchemy import create_engine
engine= create_engine('sqlite:///unicorn')

# %%
#read files
import pandas as pd
dates=pd.read_csv('datasets/dates.csv')
funding=pd.read_csv('datasets/funding.csv')
industries=pd.read_csv('datasets/industries.csv')
companies=pd.read_csv('datasets/companies.csv')

# %%
# %%sql
# sqlite:///unicorn

# %% [markdown]
# ### Drop tables if exist on databese
# In case if you rerun the notebook and table were already created

# %% [markdown]
# We use %%sql at the beginning of cell to announce that we will use SQL syntax inside that cell

# %%
# %%sql
# DROP TABLE IF EXISTS industries
# Out:
#  * sqlite:///unicorn
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS dates
# Out:
#  * sqlite:///unicorn
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS funding
# Out:
#  * sqlite:///unicorn
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS  companies
# Out:
#  * sqlite:///unicorn
# Done.
# []

# %%
#Write records stored in a DataFrame to a SQL database as a table.
dates.to_sql('dates', engine)
funding.to_sql('funding', engine)
industries.to_sql('industries', engine)
companies.to_sql('companies', engine)

# %% [markdown]
# ## show your tabels

# %%
# %%sql
# SELECT * FROM dates
# limit 3
# Out:
#  * sqlite:///unicorn
# Done.
# [(0, 189, '2017-06-24T00:00:00.000Z', 1919),
#  (1, 848, '2021-06-01T00:00:00.000Z', 2019),
#  (2, 556, '2022-02-15T00:00:00.000Z', 2011)]

# %%
# %%sql
# SELECT * FROM companies
# limit 3
# Out:
#  * sqlite:///unicorn
# Done.
# [(0, 189, 'Otto Bock HealthCare', 'Duderstadt', 'Germany', 'Europe'),
#  (1, 848, 'Matrixport', None, 'Singapore', 'Asia'),
#  (2, 556, 'Cloudinary', 'Santa Clara', 'United States', 'North America')]

# %%
# %%sql
# SELECT * FROM funding
# limit 3
# Out:
#  * sqlite:///unicorn
# Done.
# [(0, 189, 4000000000, 0, 'EQT Partners'),
#  (1, 848, 1000000000, 100000000, '"Dragonfly Captial, Qiming Venture Partners, DST Global"'),
#  (2, 556, 2000000000, 100000000, '"Blackstone, Bessemer Venture Partners"')]

# %%
# %%sql
# SELECT *
# FROM industries
# limit 3
# Out:
#  * sqlite:///unicorn
# Done.
# [(0, 189, 'Health'),
#  (1, 848, 'Fintech'),
#  (2, 556, 'Internet software & services')]

# %% [markdown]
# ## 1- identify the three best-performing industries based on the number of new unicorns created over the last three years (2019, 2020, and 2021) combined.
#
# ### Keys
# - new high-value companies are emerging.
# - competitive insight as to industry trends
#
# Your task is to first identify the three best-performing industries based on the number of new unicorns created over the last three years (2019, 2020, and 2021) combined.

# %%
# %%sql
# SELECT i.industry, count(c.company_id)
# FROM companies c
# JOIN industries i
# ON c.company_id = i.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# WHERE strftime('%Y',d.date_joined) IN ('2019', '2020', '2021')
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 3;
# Out:
#  * sqlite:///unicorn
# Done.
# [('Fintech', 173),
#  ('Internet software & services', 152),
#  ('E-commerce & direct-to-consumer', 75)]

# %% [markdown]
# ### create table with name "top3_ind"

# %%
# %%sql
# CREATE VIEW top3_ind AS
#
# SELECT i.industry, count(c.company_id)
# FROM companies c
# JOIN industries i
# ON c.company_id = i.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# WHERE strftime('%Y',d.date_joined) IN ('2019', '2020', '2021')
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 3
# Out:
#  * sqlite:///unicorn
# (sqlite3.OperationalError) table top3_ind already exists
# [SQL: CREATE VIEW top3_ind AS
#
# SELECT i.industry, count(c.company_id)
# FROM companies c
# JOIN industries i
# ON c.company_id = i.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# WHERE strftime('%Y',d.date_joined) IN ('2019', '2020', '2021')
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 3]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# - Test the new table

# %%
# %%sql
# select * from top3_ind
# Out:
#  * sqlite:///unicorn
# Done.
# [('Fintech', 173),
#  ('Internet software & services', 152),
#  ('E-commerce & direct-to-consumer', 75)]

# %% [markdown]
# - Use industries in top_ind table to filter the result of our next query

# %%
# %%sql
# SELECT i.industry,
# strftime('%Y',d.date_joined) AS year,
# count(c.company) AS num_unicorns,
# ROUND(CAST(AVG(f.valuation/1000000000)AS NUMERIC),2) AS avg_bilion_valuation
# FROM funding f
# JOIN companies c
# ON f.company_id=c.company_id
# join industries i
# ON i.company_id = c.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# WHERE year IN ('2019','2020','2021')
# AND i.industry IN (SELECT industry FROM top3_ind)
# GROUP BY 1,2
# ORDER BY 1,2 DESC, 3 , 4
# Out:
#  * sqlite:///unicorn
# Done.
# [('E-commerce & direct-to-consumer', '2021', 47, 2.47),
#  ('E-commerce & direct-to-consumer', '2020', 16, 4.0),
#  ('E-commerce & direct-to-consumer', '2019', 12, 2.58),
#  ('Fintech', '2021', 138, 2.75),
#  ('Fintech', '2020', 15, 4.33),
#  ('Fintech', '2019', 20, 6.8),
#  ('Internet software & services', '2021', 119, 2.15),
#  ('Internet software & services', '2020', 20, 4.35),
#  ('Internet software & services', '2019', 13, 4.23)]

# %% [markdown]
# ## 2 - Check unicorn companines over continent during the last three years (2019, 2020, and 2021) combined.

# %%
# %%sql
# SELECT c.continent,
# strftime('%Y',d.date_joined) AS year,
# count(c.company) AS num_unicorns,
# ROUND(CAST(AVG(f.valuation/1000000000)AS NUMERIC),2) AS avg_bilion_valuation
# FROM funding f
# JOIN companies c
# ON f.company_id=c.company_id
# join industries i
# ON i.company_id = c.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# WHERE year IN ('2019','2020','2021')
# GROUP BY 1,2
# ORDER BY 1,2 DESC, 3 DESC, 4 DESC
# Out:
#  * sqlite:///unicorn
# Done.
# [('Africa', '2021', 2, 2.0),
#  ('Asia', '2021', 116, 2.05),
#  ('Asia', '2020', 27, 3.7),
#  ('Asia', '2019', 36, 2.53),
#  ('Europe', '2021', 66, 2.45),
#  ('Europe', '2020', 11, 3.09),
#  ('Europe', '2019', 18, 6.22),
#  ('North America', '2021', 324, 2.36),
#  ('North America', '2020', 67, 3.81),
#  ('North America', '2019', 45, 5.27),
#  ('Oceania', '2021', 4, 1.5),
#  ('Oceania', '2019', 1, 6.0),
#  ('South America', '2021', 8, 1.75),
#  ('South America', '2020', 3, 4.33),
#  ('South America', '2019', 4, 2.75)]

# %% [markdown]
# ##  3 - What is the first unicorn company?

# %%
# %%sql
# SELECT
# c.company,
# c.continent,
# c.country,
# i.industry,
# d.date_joined,
# d.year_founded,
# f.select_investors,
# f.valuation,
# f.funding
# FROM funding f
# JOIN companies c
# ON f.company_id=c.company_id
# join industries i
# ON i.company_id = c.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# WHERE d.date_joined < 2008
# Out:
#  * sqlite:///unicorn
# Done.
# [('Veepee', 'Europe', 'France', 'E-commerce & direct-to-consumer', '2007-07-02T00:00:00.000Z', 2001, '"Summit Partners, Qatar Holding"', 1000000000, 0)]

# %% [markdown]
# ## 4 - Check number of companies over years

# %%
# %%sql
# SELECT strftime('%Y',d.date_joined) AS year,
# count(c.company) AS num_unicorns,
# ROUND(CAST(AVG(f.valuation/1000000000)AS NUMERIC),2) AS avg_bilion_valuation
# FROM funding f
# JOIN companies c
# ON f.company_id=c.company_id
# join industries i
# ON i.company_id = c.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# GROUP BY 1
# ORDER BY 1 DESC, 2 DESC
# Out:
#  * sqlite:///unicorn
# Done.
# [('2022', 116, 1.72),
#  ('2021', 520, 2.29),
#  ('2020', 108, 3.72),
#  ('2019', 104, 4.39),
#  ('2018', 103, 5.72),
#  ('2017', 44, 7.91),
#  ('2016', 21, 4.1),
#  ('2015', 35, 2.4),
#  ('2014', 13, 12.77),
#  ('2013', 3, 2.0),
#  ('2012', 4, 32.75),
#  ('2011', 2, 26.0),
#  ('2007', 1, 1.0)]

# %% [markdown]
# ## 5 - Get percentage of unicorn companies at 2021 to the total

# %%
# %%sql
# SELECT
#     ROUND(CAST(count(company) AS FLAOT) * 100
#       / (SELECT CAST (count(company) AS FLOAT) from companies),2) AS Unicorn_2021_percantage
# from companies c
# JOIN dates d
# ON c.company_id = d.company_id
# WHERE  strftime('%Y',d.date_joined) = '2021'
# Out:
#  * sqlite:///unicorn
# Done.
# [(48.42,)]

# %% [markdown]
# ## 6 - Since about 50% of companines joined the club at 2021, lets check the  industry category of these companies

# %%
# %%sql
# SELECT i.industry,  count(c.company) AS num_unicorns
# FROM industries i
# JOIN companies c
# ON i.company_id=c.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# WHERE strftime('%Y',d.date_joined) = '2021'
# GROUP BY 1
# ORDER BY 2 DESC
# Out:
#  * sqlite:///unicorn
# Done.
# [('Fintech', 138),
#  ('Internet software & services', 119),
#  ('E-commerce & direct-to-consumer', 47),
#  ('Health', 40),
#  ('Artificial intelligence', 36),
#  ('Cybersecurity', 27),
#  ('"Supply chain, logistics, & delivery"', 25),
#  ('Other', 21),
#  ('Data management & analytics', 21),
#  ('Hardware', 14),
#  ('Edtech', 12),
#  ('Consumer & retail', 7),
#  ('Mobile & telecommunications', 6),
#  ('Auto & transportation', 4),
#  ('Travel', 3)]

# %% [markdown]
# ## 7 - How many years it take to join to unicorn club?

# %%
# %%sql
# SELECT
# c.company,
# c.continent,
# c.country,
# i.industry,
# strftime('%Y',d.date_joined) AS year_joined,
# d.year_founded,
# CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) AS years_to_be_unicorn
# FROM funding f
# JOIN companies c
# ON f.company_id=c.company_id
# join industries i
# ON i.company_id = c.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# ORDER BY 7
# limit 15
# Out:
#  * sqlite:///unicorn
# Done.
# [('Yidian Zixun', 'Asia', 'China', 'Mobile & telecommunications', '2017', 2021, -4),
#  ('candy.com', 'North America', 'United States', 'Fintech', '2021', 2021, 0),
#  ('Playco', 'Asia', 'Japan', 'Other', '2020', 2020, 0),
#  ('GlobalBees', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2021', 2021, 0),
#  ('Flink Food', 'Europe', 'Germany', 'E-commerce & direct-to-consumer', '2021', 2021, 0),
#  ('Mensa Brands', 'Asia', 'India', 'Other', '2021', 2021, 0),
#  ('ClickHouse', 'North America', 'United States', 'Data management & analytics', '2021', 2021, 0),
#  ('Jokr', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2021', 2021, 0),
#  ('Avant', 'North America', 'United States', 'Artificial intelligence', '2012', 2012, 0),
#  ('Ola Electric Mobility', 'Asia', 'India', 'Auto & transportation', '2019', 2019, 0),
#  ('PLACE', 'North America', 'United States', 'Internet software & services', '2021', 2020, 1),
#  ('HAYDON', 'Asia', 'China', 'Consumer & retail', '2021', 2020, 1),
#  ('Clara', 'North America', 'Mexico', 'Fintech', '2021', 2020, 1),
#  ('Clubhouse', 'North America', 'United States', 'Mobile & telecommunications', '2021', 2020, 1),
#  ('Apus Group', 'Asia', 'China', 'Mobile & telecommunications', '2015', 2014, 1)]

# %% [markdown]
#  We noticed wrong data for Yidian Zixun as date of joining to unicorn club before year of foundation date

# %% [markdown]
# ### To get clear vision lets bin the years to goin unicorn club to smaller groups

# %%
# %%sql
# SELECT
# c.company,
# c.continent,
# c.country,
# i.industry,
# strftime('%Y',d.date_joined) AS year_joined,
# d.year_founded,
# CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) AS years_to_be_unicorn,
#     CASE WHEN
#               CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 2 THEN '0 to 2'
#         WHEN CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 5  AND
#              CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) > 2 THEN '3 to 5'
#         WHEN CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 10  AND
#              CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) > 5  THEN '6 to 10'
#         WHEN CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 25  AND
#              CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) > 10  THEN '11 to 25'
#         ELSE '+ 25'
#         END AS year_window_to_be_unicorn
# FROM funding f
# JOIN companies c
# ON f.company_id=c.company_id
# join industries i
# ON i.company_id = c.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# ORDER BY 7
# --limit 15
# Out:
#  * sqlite:///unicorn
# Done.
# [('Yidian Zixun', 'Asia', 'China', 'Mobile & telecommunications', '2017', 2021, -4, '0 to 2'),
#  ('candy.com', 'North America', 'United States', 'Fintech', '2021', 2021, 0, '0 to 2'),
#  ('Playco', 'Asia', 'Japan', 'Other', '2020', 2020, 0, '0 to 2'),
#  ('GlobalBees', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2021', 2021, 0, '0 to 2'),
#  ('Flink Food', 'Europe', 'Germany', 'E-commerce & direct-to-consumer', '2021', 2021, 0, '0 to 2'),
#  ('Mensa Brands', 'Asia', 'India', 'Other', '2021', 2021, 0, '0 to 2'),
#  ('ClickHouse', 'North America', 'United States', 'Data management & analytics', '2021', 2021, 0, '0 to 2'),
#  ('Jokr', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2021', 2021, 0, '0 to 2'),
#  ('Avant', 'North America', 'United States', 'Artificial intelligence', '2012', 2012, 0, '0 to 2'),
#  ('Ola Electric Mobility', 'Asia', 'India', 'Auto & transportation', '2019', 2019, 0, '0 to 2'),
#  ('PLACE', 'North America', 'United States', 'Internet software & services', '2021', 2020, 1, '0 to 2'),
#  ('HAYDON', 'Asia', 'China', 'Consumer & retail', '2021', 2020, 1, '0 to 2'),
#  ('Clara', 'North America', 'Mexico', 'Fintech', '2021', 2020, 1, '0 to 2'),
#  ('Clubhouse', 'North America', 'United States', 'Mobile & telecommunications', '2021', 2020, 1, '0 to 2'),
#  ('Apus Group', 'Asia', 'China', 'Mobile & telecommunications', '2015', 2014, 1, '0 to 2'),
#  ('Phantom', 'North America', 'United States', 'Fintech', '2022', 2021, 1, '0 to 2'),
#  ('Stytch', 'North America', 'United States', 'Cybersecurity', '2021', 2020, 1, '0 to 2'),
#  ('Drata', 'North America', 'United States', 'Cybersecurity', '2021', 2020, 1, '0 to 2'),
#  ('Cider', 'Asia', 'Hong Kong', 'E-commerce & direct-to-consumer', '2021', 2020, 1, '0 to 2'),
#  ('Cadence', 'North America', 'United States', 'Health', '2021', 2020, 1, '0 to 2'),
#  ('LayerZero Labs', 'North America', 'United States', 'Internet software & services', '2022', 2021, 1, '0 to 2'),
#  ('Razor', 'Europe', 'Germany', 'Consumer & retail', '2021', 2020, 1, '0 to 2'),
#  ('Airbyte', 'North America', 'United States', 'Internet software & services', '2021', 2020, 1, '0 to 2'),
#  ('Hopin', 'Europe', 'United Kingdom', 'Internet software & services', '2020', 2019, 1, '0 to 2'),
#  ('Brex', 'North America', 'United States', 'Fintech', '2018', 2017, 1, '0 to 2'),
#  ('Gorillas', 'Europe', 'Germany', 'E-commerce & direct-to-consumer', '2021', 2020, 1, '0 to 2'),
#  ('iCarbonX', 'Asia', 'China', 'Artificial intelligence', '2016', 2015, 1, '0 to 2'),
#  ('Aptos', 'North America', 'United States', 'Internet software & services', '2022', 2021, 1, '0 to 2'),
#  ('Pacaso', 'North America', 'United States', 'Fintech', '2021', 2020, 1, '0 to 2'),
#  ('Uptake', 'North America', 'United States', 'Artificial intelligence', '2015', 2014, 1, '0 to 2'),
#  ('Noname Security', 'North America', 'United States', 'Cybersecurity', '2021', 2020, 1, '0 to 2'),
#  ('Biren Technology', 'Asia', 'China', 'Hardware', '2020', 2019, 1, '0 to 2'),
#  ('Devoted Health', 'North America', 'United States', 'Health', '2018', 2017, 1, '0 to 2'),
#  ('58 Daojia', 'Asia', 'China', 'Internet software & services', '2015', 2014, 1, '0 to 2'),
#  ('Merama', 'North America', 'Mexico', 'E-commerce & direct-to-consumer', '2021', 2020, 1, '0 to 2'),
#  ('Yuga Labs', 'North America', 'United States', 'Fintech', '2022', 2021, 1, '0 to 2'),
#  ('Nexii', 'North America', 'Canada', 'Other', '2021', 2020, 1, '0 to 2'),
#  ('Cerebral', 'North America', 'United States', 'Health', '2021', 2020, 1, '0 to 2'),
#  ('Chehaoduo', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2016', 2015, 1, '0 to 2'),
#  ('Wiz', 'Asia', 'Israel', 'Cybersecurity', '2021', 2020, 1, '0 to 2'),
#  ('Scale AI', 'North America', 'United States', 'Artificial intelligence', '2019', 2018, 1, '0 to 2'),
#  ('Black Unicorn Factory', 'North America', 'United States', 'Other', '2021', 2020, 1, '0 to 2'),
#  ('EQRx', 'North America', 'United States', 'Health', '2021', 2020, 1, '0 to 2'),
#  ('SellerX', 'Europe', 'Germany', 'E-commerce & direct-to-consumer', '2021', 2020, 1, '0 to 2'),
#  ('AIWAYS', 'Asia', 'China', 'Auto & transportation', '2018', 2017, 1, '0 to 2'),
#  ('Xiaobing', 'Asia', 'China', 'Fintech', '2021', 2020, 1, '0 to 2'),
#  ('Matrixport', 'Asia', 'Singapore', 'Fintech', '2021', 2019, 2, '0 to 2'),
#  ('Worldcoin', 'North America', 'United States', 'Fintech', '2021', 2019, 2, '0 to 2'),
#  ('JimuBox', 'Asia', 'China', 'Fintech', '2015', 2013, 2, '0 to 2'),
#  ('Snorkel AI', 'North America', 'United States', 'Artificial intelligence', '2021', 2019, 2, '0 to 2'),
#  ('JUUL Labs', 'North America', 'United States', 'Consumer & retail', '2017', 2015, 2, '0 to 2'),
#  ('Rebellion Defense', 'North America', 'United States', 'Artificial intelligence', '2021', 2019, 2, '0 to 2'),
#  ('Mercury', 'North America', 'United States', 'Fintech', '2021', 2019, 2, '0 to 2'),
#  ('Haomao.AI', 'Asia', 'China', 'Artificial intelligence', '2021', 2019, 2, '0 to 2'),
#  ('Revolution Precrafted', 'Asia', 'Philippines', 'Other', '2017', 2015, 2, '0 to 2'),
#  ('Anyscale', 'North America', 'United States', 'Artificial intelligence', '2021', 2019, 2, '0 to 2'),
#  ('apna', 'Asia', 'India', 'Internet software & services', '2021', 2019, 2, '0 to 2'),
#  ('Meicai', 'Asia', 'China', 'Mobile & telecommunications', '2016', 2014, 2, '0 to 2'),
#  ('BYTON', 'Asia', 'China', 'Auto & transportation', '2018', 2016, 2, '0 to 2'),
#  ('Pony.ai', 'North America', 'United States', 'Artificial intelligence', '2018', 2016, 2, '0 to 2'),
#  ('Faire', 'North America', 'United States', 'Artificial intelligence', '2019', 2017, 2, '0 to 2'),
#  ('OakNorth Bank', 'Europe', 'United Kingdom', 'Fintech', '2017', 2015, 2, '0 to 2'),
#  ('SaltPay', 'Europe', 'United Kingdom', 'Fintech', '2021', 2019, 2, '0 to 2'),
#  ('Udaan', 'Asia', 'India', '"Supply chain, logistics, & delivery"', '2018', 2016, 2, '0 to 2'),
#  ('Momenta', 'Asia', 'China', 'Artificial intelligence', '2018', 2016, 2, '0 to 2'),
#  ('Abogen', 'Asia', 'China', 'Health', '2021', 2019, 2, '0 to 2'),
#  ('Lessen', 'North America', 'United States', 'Internet software & services', '2021', 2019, 2, '0 to 2'),
#  ('Island', 'North America', 'United States', 'Internet software & services', '2022', 2020, 2, '0 to 2'),
#  ('Yello Mobile', 'Asia', 'South Korea', 'Mobile & telecommunications', '2014', 2012, 2, '0 to 2'),
#  ('Whatnot', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2021', 2019, 2, '0 to 2'),
#  ('Amount', 'North America', 'United States', 'Fintech', '2021', 2019, 2, '0 to 2'),
#  ('Chronosphere', 'North America', 'United States', 'Data management & analytics', '2021', 2019, 2, '0 to 2'),
#  ('DT Dream', 'Asia', 'China', 'Data management & analytics', '2017', 2015, 2, '0 to 2'),
#  ('BenevolentAI', 'Europe', 'United Kingdom', 'Artificial intelligence', '2015', 2013, 2, '0 to 2'),
#  ('Transcarent', 'North America', 'United States', 'Health', '2022', 2020, 2, '0 to 2'),
#  ('Fair', 'North America', 'United States', 'Auto & transportation', '2018', 2016, 2, '0 to 2'),
#  ('Hello TransTech', 'Asia', 'China', 'Auto & transportation', '2018', 2016, 2, '0 to 2'),
#  ('Thrasio', 'North America', 'United States', 'Other', '2020', 2018, 2, '0 to 2'),
#  ('C6 Bank', 'South America', 'Brazil', 'Fintech', '2020', 2018, 2, '0 to 2'),
#  ('SmartMore', 'Asia', 'China', 'Artificial intelligence', '2021', 2019, 2, '0 to 2'),
#  ('Sky Mavis', 'Asia', 'Vietnam', 'Internet software & services', '2021', 2019, 2, '0 to 2'),
#  ('Prime Medicine', 'North America', 'United States', 'Health', '2021', 2019, 2, '0 to 2'),
#  ('Elemy', 'North America', 'United States', 'Health', '2021', 2019, 2, '0 to 2'),
#  ('HMD Global', 'Europe', 'Finland', 'Mobile & telecommunications', '2018', 2016, 2, '0 to 2'),
#  ('Rohlik', 'Europe', 'Czech Republic', '"Supply chain, logistics, & delivery"', '2021', 2019, 2, '0 to 2'),
#  ('Fiture', 'Asia', 'China', 'Health', '2021', 2019, 2, '0 to 2'),
#  ('Skims', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2021', 2019, 2, '0 to 2'),
#  ('SVOLT', 'Asia', 'China', 'Auto & transportation', '2020', 2018, 2, '0 to 2'),
#  ('Instacart', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2014', 2012, 2, '0 to 2'),
#  ('Better.com', 'North America', 'United States', 'Fintech', '2020', 2018, 2, '0 to 2'),
#  ('Dream Games', 'Europe', 'Turkey', 'Mobile & telecommunications', '2021', 2019, 2, '0 to 2'),
#  ('NuCom Group', 'Europe', 'Germany', 'Other', '2018', 2016, 2, '0 to 2'),
#  ('Aura', 'North America', 'United States', 'Cybersecurity', '2021', 2019, 2, '0 to 2'),
#  ('LinkSure Network', 'Asia', 'China', 'Mobile & telecommunications', '2015', 2013, 2, '0 to 2'),
#  ('MoonPay', 'North America', 'United States', 'Fintech', '2021', 2019, 2, '0 to 2'),
#  ('Illumio', 'North America', 'United States', 'Cybersecurity', '2015', 2013, 2, '0 to 2'),
#  ('Pipe', 'North America', 'United States', 'Fintech', '2021', 2019, 2, '0 to 2'),
#  ('Upgrade', 'North America', 'United States', 'Fintech', '2018', 2016, 2, '0 to 2'),
#  ('Pat McGrath Labs', 'North America', 'United States', 'Consumer & retail', '2018', 2016, 2, '0 to 2'),
#  ('Orca Security', 'North America', 'United States', 'Cybersecurity', '2021', 2019, 2, '0 to 2'),
#  ('Axelar', 'North America', 'Canada', 'Internet software & services', '2022', 2020, 2, '0 to 2'),
#  ('Yipin Shengxian', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2019', 2017, 2, '0 to 2'),
#  ('Ramp', 'North America', 'United States', 'Fintech', '2021', 2019, 2, '0 to 2'),
#  ('Carbon', 'North America', 'United States', 'Hardware', '2015', 2013, 2, '0 to 2'),
#  ('Graphcore', 'Europe', 'United Kingdom', 'Artificial intelligence', '2018', 2016, 2, '0 to 2'),
#  ('Anduril', 'North America', 'United States', 'Artificial intelligence', '2019', 2017, 2, '0 to 2'),
#  ('Cerebras Systems', 'North America', 'United States', 'Hardware', '2018', 2016, 2, '0 to 2'),
#  ('Sorare', 'Europe', 'France', 'E-commerce & direct-to-consumer', '2021', 2019, 2, '0 to 2'),
#  ('Niantic', 'North America', 'United States', 'Mobile & telecommunications', '2017', 2015, 2, '0 to 2'),
#  ('Loft', 'South America', 'Brazil', 'E-commerce & direct-to-consumer', '2020', 2018, 2, '0 to 2'),
#  ('Zhuan Zhuan', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2017', 2015, 2, '0 to 2'),
#  ('SITECH DEV', 'Asia', 'China', 'Other', '2019', 2017, 2, '0 to 2'),
#  ('Uplight', 'North America', 'United States', 'Other', '2021', 2019, 2, '0 to 2'),
#  ('Assembly', 'North America', 'United States', 'Internet software & services', '2021', 2019, 2, '0 to 2'),
#  ('MobileCoin', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('AgentSync', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Offchain Labs', 'North America', 'United States', 'Internet software & services', '2021', 2018, 3, '3 to 5'),
#  ('Turing', 'North America', 'United States', 'Internet software & services', '2021', 2018, 3, '3 to 5'),
#  ('Temporal', 'North America', 'United States', 'Internet software & services', '2022', 2019, 3, '3 to 5'),
#  ('Wrapbook', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Chief', 'North America', 'United States', 'Other', '2022', 2019, 3, '3 to 5'),
#  ('Panther Labs', 'North America', 'United States', 'Cybersecurity', '2021', 2018, 3, '3 to 5'),
#  ('StarkWare', 'Asia', 'Israel', 'Cybersecurity', '2021', 2018, 3, '3 to 5'),
#  ('Sidecar Health', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Figment', 'North America', 'Canada', 'Internet software & services', '2021', 2018, 3, '3 to 5'),
#  ('Pristyn Care', 'Asia', 'India', 'Health', '2021', 2018, 3, '3 to 5'),
#  ('Optimism', 'North America', 'United States', 'Internet software & services', '2022', 2019, 3, '3 to 5'),
#  ('Injective Protocol', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Modern Treasury', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Changingedu', 'Asia', 'China', 'Edtech', '2017', 2014, 3, '3 to 5'),
#  ('Hive Box', 'Asia', 'China', '"Supply chain, logistics, & delivery"', '2018', 2015, 3, '3 to 5'),
#  ('4Paradigm', 'Asia', 'China', 'Artificial intelligence', '2018', 2015, 3, '3 to 5'),
#  ('Leap Motor', 'Asia', 'China', 'Auto & transportation', '2018', 2015, 3, '3 to 5'),
#  ('Fireblocks', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Monzo', 'Europe', 'United Kingdom', 'Fintech', '2018', 2015, 3, '3 to 5'),
#  ('Indigo Ag', 'North America', 'United States', 'Artificial intelligence', '2017', 2014, 3, '3 to 5'),
#  ('WeRide', 'Asia', 'China', 'Auto & transportation', '2020', 2017, 3, '3 to 5'),
#  ('VIPKid', 'Asia', 'China', 'Edtech', '2016', 2013, 3, '3 to 5'),
#  ('Ro', 'North America', 'United States', 'Health', '2020', 2017, 3, '3 to 5'),
#  ('Wave', 'Africa', 'Senegal', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Next Silicon', 'Asia', 'Israel', 'Hardware', '2021', 2018, 3, '3 to 5'),
#  ('Beyond Identity', 'North America', 'United States', 'Cybersecurity', '2022', 2019, 3, '3 to 5'),
#  ('bolttech', 'Asia', 'Singapore', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Persona', 'North America', 'United States', 'Cybersecurity', '2021', 2018, 3, '3 to 5'),
#  ('Aleo', 'North America', 'United States', 'Cybersecurity', '2022', 2019, 3, '3 to 5'),
#  ('Spotter', 'North America', 'United States', 'Fintech', '2022', 2019, 3, '3 to 5'),
#  ('Wayflyer', 'Europe', 'Ireland', 'Fintech', '2022', 2019, 3, '3 to 5'),
#  ('TaxBit', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Agile Robots', 'Europe', 'Germany', 'Hardware', '2021', 2018, 3, '3 to 5'),
#  ('Ajaib', 'Asia', 'Indonesia', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Mythical Games', 'North America', 'United States', 'Internet software & services', '2021', 2018, 3, '3 to 5'),
#  ('Firebolt', 'Asia', 'Israel', 'Data management & analytics', '2022', 2019, 3, '3 to 5'),
#  ('Jeeves', 'North America', 'United States', 'Fintech', '2022', 2019, 3, '3 to 5'),
#  ('Meero', 'Europe', 'France', 'Artificial intelligence', '2019', 2016, 3, '3 to 5'),
#  ('REEF Technology', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2018', 2015, 3, '3 to 5'),
#  ('Revolut', 'Europe', 'United Kingdom', 'Fintech', '2018', 2015, 3, '3 to 5'),
#  ('FTX', 'North America', 'Bahamas', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Nuro', 'North America', 'United States', 'Auto & transportation', '2019', 2016, 3, '3 to 5'),
#  ('Rappi', 'South America', 'Colombia', '"Supply chain, logistics, & delivery"', '2018', 2015, 3, '3 to 5'),
#  ('Savage X Fenty', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2021', 2018, 3, '3 to 5'),
#  ('FalconX', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Zilch', 'Europe', 'United Kingdom', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Applied Intuition', 'North America', 'United States', 'Data management & analytics', '2020', 2017, 3, '3 to 5'),
#  ('Bordrin Motors', 'Asia', 'China', 'Auto & transportation', '2019', 2016, 3, '3 to 5'),
#  ('Unqork', 'North America', 'United States', 'Fintech', '2020', 2017, 3, '3 to 5'),
#  ('Mobile Premier League', 'Asia', 'India', 'Internet software & services', '2021', 2018, 3, '3 to 5'),
#  ('Scalapay', 'Europe', 'Italy', 'Fintech', '2022', 2019, 3, '3 to 5'),
#  ('Ankorstore', 'Europe', 'France', 'E-commerce & direct-to-consumer', '2022', 2019, 3, '3 to 5'),
#  ('Zume', 'North America', 'United States', 'Consumer & retail', '2018', 2015, 3, '3 to 5'),
#  ('Geek+', 'Asia', 'China', 'Hardware', '2018', 2015, 3, '3 to 5'),
#  ('Rippling', 'North America', 'United States', 'Internet software & services', '2020', 2017, 3, '3 to 5'),
#  ('Enflame', 'Asia', 'China', 'Hardware', '2021', 2018, 3, '3 to 5'),
#  ('Grove Collaborative', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2019', 2016, 3, '3 to 5'),
#  ('Royole Corporation', 'Asia', 'China', 'Hardware', '2015', 2012, 3, '3 to 5'),
#  ('StockX', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2019', 2016, 3, '3 to 5'),
#  ('Northvolt', 'Europe', 'Sweden', 'Other', '2019', 2016, 3, '3 to 5'),
#  ('Argo AI', 'North America', 'United States', 'Artificial intelligence', '2019', 2016, 3, '3 to 5'),
#  ('Melio', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Kitopi', 'Asia', 'United Arab Emirates', '"Supply chain, logistics, & delivery"', '2021', 2018, 3, '3 to 5'),
#  ('Symphony', 'North America', 'United States', 'Fintech', '2017', 2014, 3, '3 to 5'),
#  ('CloudWalk Technology', 'Asia', 'China', 'Artificial intelligence', '2018', 2015, 3, '3 to 5'),
#  ('VOI', 'Europe', 'Sweden', 'Travel', '2021', 2018, 3, '3 to 5'),
#  ('HuiMin', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2016', 2013, 3, '3 to 5'),
#  ('Misfits Market', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2021', 2018, 3, '3 to 5'),
#  ('ClickUp', 'North America', 'United States', 'Internet software & services', '2020', 2017, 3, '3 to 5'),
#  ('Cgtz', 'Asia', 'China', 'Fintech', '2017', 2014, 3, '3 to 5'),
#  ('Nxin', 'Asia', 'China', 'Internet software & services', '2018', 2015, 3, '3 to 5'),
#  ('Zetwerk', 'Asia', 'India', 'Internet software & services', '2021', 2018, 3, '3 to 5'),
#  ('Rubrik', 'North America', 'United States', 'Data management & analytics', '2017', 2014, 3, '3 to 5'),
#  ('Opay', 'Africa', 'Nigeria', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Tier', 'Europe', 'Germany', 'Travel', '2021', 2018, 3, '3 to 5'),
#  ('Kuaikan Manhua', 'Asia', 'China', 'Internet software & services', '2017', 2014, 3, '3 to 5'),
#  ('BharatPe', 'Asia', 'India', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Dapper Labs', 'North America', 'Canada', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('TERMINUS Technology', 'Asia', 'China', 'Hardware', '2018', 2015, 3, '3 to 5'),
#  ('Deel', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Convoy', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2018', 2015, 3, '3 to 5'),
#  ('Banma Network Technologies', 'Asia', 'China', 'Auto & transportation', '2018', 2015, 3, '3 to 5'),
#  ('Watershed', 'North America', 'United States', 'Internet software & services', '2022', 2019, 3, '3 to 5'),
#  ('Cao Cao Mobility', 'Asia', 'China', 'Auto & transportation', '2018', 2015, 3, '3 to 5'),
#  ('Bitmain', 'Asia', 'China', 'Hardware', '2018', 2015, 3, '3 to 5'),
#  ('Rapyd', 'Europe', 'United Kingdom', 'Fintech', '2019', 2016, 3, '3 to 5'),
#  ('Zihaiguo', 'Asia', 'China', 'Consumer & retail', '2021', 2018, 3, '3 to 5'),
#  ('Tempus', 'North America', 'United States', 'Health', '2018', 2015, 3, '3 to 5'),
#  ('Next Insurance', 'North America', 'United States', 'Fintech', '2019', 2016, 3, '3 to 5'),
#  ('Cityblock Health', 'North America', 'United States', 'Health', '2020', 2017, 3, '3 to 5'),
#  ('The Bank of London', 'Europe', 'United Kingdom', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('Forte Labs', 'North America', 'United States', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('TripActions', 'North America', 'United States', 'Travel', '2018', 2015, 3, '3 to 5'),
#  ('Xiaohongshu', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2016', 2013, 3, '3 to 5'),
#  ('CRED', 'Asia', 'India', 'Fintech', '2021', 2018, 3, '3 to 5'),
#  ('OneTrust', 'North America', 'United States', 'Internet software & services', '2019', 2016, 3, '3 to 5'),
#  ('eDaili', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2019', 2015, 4, '3 to 5'),
#  ('EcoFlow', 'Asia', 'China', 'Hardware', '2021', 2017, 4, '3 to 5'),
#  ('CoinDCX', 'Asia', 'India', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Masterworks', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Marshmallow', 'Europe', 'United Kingdom', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('CoinList', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('1047 Games', 'North America', 'United States', 'Internet software & services', '2021', 2017, 4, '3 to 5'),
#  ('iTrustCapital', 'North America', 'United States', 'Fintech', '2022', 2018, 4, '3 to 5'),
#  ('Rightway', 'North America', 'United States', 'Health', '2021', 2017, 4, '3 to 5'),
#  ('Lamabang', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2015', 2011, 4, '3 to 5'),
#  ('Instabase', 'North America', 'United States', 'Data management & analytics', '2019', 2015, 4, '3 to 5'),
#  ('Juanpi', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2016', 2012, 4, '3 to 5'),
#  ('Verkada', 'North America', 'United States', 'Cybersecurity', '2020', 2016, 4, '3 to 5'),
#  ('Preferred Networks', 'Asia', 'Japan', 'Artificial intelligence', '2018', 2014, 4, '3 to 5'),
#  ('Gem', 'North America', 'United States', 'Internet software & services', '2021', 2017, 4, '3 to 5'),
#  ('GalaxySpace', 'Asia', 'China', 'Mobile & telecommunications', '2020', 2016, 4, '3 to 5'),
#  ('Modern Health', 'North America', 'United States', 'Health', '2021', 2017, 4, '3 to 5'),
#  ('Solo.io', 'North America', 'United States', 'Internet software & services', '2021', 2017, 4, '3 to 5'),
#  ('Away', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2019', 2015, 4, '3 to 5'),
#  ('Orca Bio', 'North America', 'United States', 'Health', '2020', 2016, 4, '3 to 5'),
#  ('Accelerant', 'Europe', 'United Kingdom', 'Other', '2022', 2018, 4, '3 to 5'),
#  ('IRL', 'North America', 'United States', 'Internet software & services', '2021', 2017, 4, '3 to 5'),
#  ('SambaNova Systems', 'North America', 'United States', 'Data management & analytics', '2021', 2017, 4, '3 to 5'),
#  ('Relativity Space', 'North America', 'United States', 'Other', '2020', 2016, 4, '3 to 5'),
#  ('OpenAI', 'North America', 'United States', 'Artificial intelligence', '2019', 2015, 4, '3 to 5'),
#  ('Youxia Motors', 'Asia', 'China', 'Auto & transportation', '2018', 2014, 4, '3 to 5'),
#  ('ENOVATE', 'Asia', 'China', 'Auto & transportation', '2019', 2015, 4, '3 to 5'),
#  ('BlockFi', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('People.ai', 'North America', 'United States', 'Internet software & services', '2021', 2017, 4, '3 to 5'),
#  ('Weights & Biases', 'North America', 'United States', 'Internet software & services', '2021', 2017, 4, '3 to 5'),
#  ('Betterfly', 'South America', 'Chile', 'Artificial intelligence', '2022', 2018, 4, '3 to 5'),
#  ('Shukun Technology', 'Asia', 'China', 'Artificial intelligence', '2021', 2017, 4, '3 to 5'),
#  ('Hailo', 'Asia', 'Israel', 'Artificial intelligence', '2021', 2017, 4, '3 to 5'),
#  ('Baiwang', 'Asia', 'China', 'Fintech', '2019', 2015, 4, '3 to 5'),
#  ('BeiBei', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2015', 2011, 4, '3 to 5'),
#  ('Mia.com', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2015', 2011, 4, '3 to 5'),
#  ('Deliverect', 'Europe', 'Belgium', 'Fintech', '2022', 2018, 4, '3 to 5'),
#  ('Payhawk', 'Europe', 'United Kingdom', 'Fintech', '2022', 2018, 4, '3 to 5'),
#  ('Standard', 'North America', 'United States', 'Artificial intelligence', '2021', 2017, 4, '3 to 5'),
#  ('Orchard', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('LinkDoc Technology', 'Asia', 'China', 'Health', '2018', 2014, 4, '3 to 5'),
#  ('VAST Data', 'North America', 'United States', 'Data management & analytics', '2020', 2016, 4, '3 to 5'),
#  ('Mammoth Biosciences', 'North America', 'United States', 'Health', '2021', 2017, 4, '3 to 5'),
#  ('Pipa Coding', 'Asia', 'China', 'Edtech', '2021', 2017, 4, '3 to 5'),
#  ('Aibee', 'Asia', 'China', 'Artificial intelligence', '2021', 2017, 4, '3 to 5'),
#  ('Motorway', 'Europe', 'United Kingdom', 'E-commerce & direct-to-consumer', '2021', 2017, 4, '3 to 5'),
#  ('ReCharge', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Immutable', 'Oceania', 'Australia', 'Fintech', '2022', 2018, 4, '3 to 5'),
#  ('FXiaoKe', 'Asia', 'China', 'Mobile & telecommunications', '2015', 2011, 4, '3 to 5'),
#  ('Epirus', 'North America', 'United States', 'Other', '2022', 2018, 4, '3 to 5'),
#  ('Il Makiage', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2022', 2018, 4, '3 to 5'),
#  ('Stripe', 'North America', 'United States', 'Fintech', '2014', 2010, 4, '3 to 5'),
#  ('Horizon Robotics', 'Asia', 'China', 'Artificial intelligence', '2019', 2015, 4, '3 to 5'),
#  ('Kavak', 'North America', 'Mexico', 'E-commerce & direct-to-consumer', '2020', 2016, 4, '3 to 5'),
#  ('ConcertAI', 'North America', 'United States', 'Artificial intelligence', '2022', 2018, 4, '3 to 5'),
#  ('Maimai', 'Asia', 'China', 'Mobile & telecommunications', '2017', 2013, 4, '3 to 5'),
#  ('CoinSwitch Kuber', 'Asia', 'India', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Chipper Cash', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Enpal', 'Europe', 'Germany', 'Internet software & services', '2021', 2017, 4, '3 to 5'),
#  ('Vox Media', 'North America', 'United States', 'Internet software & services', '2015', 2011, 4, '3 to 5'),
#  ('Globality', 'North America', 'United States', 'Artificial intelligence', '2019', 2015, 4, '3 to 5'),
#  ('Side', 'North America', 'United States', 'Internet software & services', '2021', 2017, 4, '3 to 5'),
#  ('Infinidat', 'North America', 'United States', 'Hardware', '2015', 2011, 4, '3 to 5'),
#  ('Kopi Kenangan', 'Asia', 'Indonesia', 'Consumer & retail', '2021', 2017, 4, '3 to 5'),
#  ('TechStyle Fashion Group', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2014', 2010, 4, '3 to 5'),
#  ('MindMaze', 'Europe', 'Switzerland', 'Health', '2016', 2012, 4, '3 to 5'),
#  ('Notion Labs', 'North America', 'United States', 'Internet software & services', '2020', 2016, 4, '3 to 5'),
#  ('LifeMiles', 'South America', 'Colombia', 'Other', '2015', 2011, 4, '3 to 5'),
#  ('Flash Express', 'Asia', 'Thailand', '"Supply chain, logistics, & delivery"', '2021', 2017, 4, '3 to 5'),
#  ('FlashEx', 'Asia', 'China', '"Supply chain, logistics, & delivery"', '2018', 2014, 4, '3 to 5'),
#  ('Koudai', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2014', 2010, 4, '3 to 5'),
#  ('Divvy Homes', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Guild Education', 'North America', 'United States', 'Internet software & services', '2019', 2015, 4, '3 to 5'),
#  ('Flock Safety', 'North America', 'United States', 'Hardware', '2021', 2017, 4, '3 to 5'),
#  ('Groww', 'Asia', 'India', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('ECARX', 'Asia', 'China', 'Auto & transportation', '2020', 2016, 4, '3 to 5'),
#  ('Axonius', 'North America', 'United States', 'Cybersecurity', '2021', 2017, 4, '3 to 5'),
#  ('Eightfold.ai', 'North America', 'United States', 'Internet software & services', '2020', 2016, 4, '3 to 5'),
#  ('Magic Leap', 'North America', 'United States', 'Hardware', '2014', 2010, 4, '3 to 5'),
#  ('Zuoyebang', 'Asia', 'China', 'Edtech', '2018', 2014, 4, '3 to 5'),
#  ('ABL Space Systems', 'North America', 'United States', 'Other', '2021', 2017, 4, '3 to 5'),
#  ('OpenSea', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2021', 2017, 4, '3 to 5'),
#  ('Ouyeel', 'Asia', 'China', 'Internet software & services', '2019', 2015, 4, '3 to 5'),
#  ('Tekion', 'North America', 'United States', 'Internet software & services', '2020', 2016, 4, '3 to 5'),
#  ('Deliverr', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2021', 2017, 4, '3 to 5'),
#  ('Boba', 'North America', 'United States', 'Fintech', '2022', 2018, 4, '3 to 5'),
#  ('Gauntlet Networks', 'North America', 'United States', 'Fintech', '2022', 2018, 4, '3 to 5'),
#  ('Route', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2022', 2018, 4, '3 to 5'),
#  ('Anchorage Digital', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Ola Cabs', 'Asia', 'India', 'Auto & transportation', '2014', 2010, 4, '3 to 5'),
#  ('WM Motor', 'Asia', 'China', 'Auto & transportation', '2019', 2015, 4, '3 to 5'),
#  ('Coalition', 'North America', 'United States', 'Cybersecurity', '2021', 2017, 4, '3 to 5'),
#  ('Yijiupi', 'Asia', 'China', 'Consumer & retail', '2018', 2014, 4, '3 to 5'),
#  ('Guoquan Shihui', 'Asia', 'China', 'Consumer & retail', '2021', 2017, 4, '3 to 5'),
#  ('Commure', 'North America', 'United States', 'Internet software & services', '2021', 2017, 4, '3 to 5'),
#  ('Uala', 'South America', 'Argentina', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Yimidida', 'Asia', 'China', '"Supply chain, logistics, & delivery"', '2019', 2015, 4, '3 to 5'),
#  ('Alchemy', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Swiggy', 'Asia', 'India', '"Supply chain, logistics, & delivery"', '2018', 2014, 4, '3 to 5'),
#  ('Dutchie', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2021', 2017, 4, '3 to 5'),
#  ('The Brandtech Group', 'North America', 'United States', 'Other', '2019', 2015, 4, '3 to 5'),
#  ('DealShare', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2022', 2018, 4, '3 to 5'),
#  ('Trader Interactive', 'North America', 'United States', 'Other', '2021', 2017, 4, '3 to 5'),
#  ('SpotOn', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('Kuaigou Dache', 'Asia', 'China', '"Supply chain, logistics, & delivery"', '2018', 2014, 4, '3 to 5'),
#  ('Newlink Group', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2020', 2016, 4, '3 to 5'),
#  ('Branch', 'North America', 'United States', 'Mobile & telecommunications', '2018', 2014, 4, '3 to 5'),
#  ('GoStudent', 'Europe', 'Austria', 'Edtech', '2021', 2017, 4, '3 to 5'),
#  ('Gusto', 'North America', 'United States', 'Fintech', '2015', 2011, 4, '3 to 5'),
#  ('Genki Forest', 'Asia', 'China', 'Consumer & retail', '2020', 2016, 4, '3 to 5'),
#  ('Klook', 'Asia', 'Hong Kong', 'Travel', '2018', 2014, 4, '3 to 5'),
#  ('TuJia', 'Asia', 'China', 'Travel', '2015', 2011, 4, '3 to 5'),
#  ('Medlinker', 'Asia', 'China', 'Health', '2018', 2014, 4, '3 to 5'),
#  ('Yixia', 'Asia', 'China', 'Mobile & telecommunications', '2015', 2011, 4, '3 to 5'),
#  ('Redwood Materials', 'North America', 'United States', 'Other', '2021', 2017, 4, '3 to 5'),
#  ('Dune Analytics', 'Europe', 'Norway', 'Data management & analytics', '2022', 2018, 4, '3 to 5'),
#  ('DeepBlue Technology', 'Asia', 'China', 'Artificial intelligence', '2018', 2014, 4, '3 to 5'),
#  ('Heyday', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2021', 2017, 4, '3 to 5'),
#  ('Airwallex', 'Oceania', 'Australia', 'Fintech', '2019', 2015, 4, '3 to 5'),
#  ('Attentive', 'North America', 'United States', 'Mobile & telecommunications', '2020', 2016, 4, '3 to 5'),
#  ('Celsius Network', 'North America', 'United States', 'Fintech', '2021', 2017, 4, '3 to 5'),
#  ('WeLab', 'Asia', 'Hong Kong', 'Fintech', '2017', 2013, 4, '3 to 5'),
#  ('UBTECH Robotics', 'Asia', 'China', 'Hardware', '2016', 2012, 4, '3 to 5'),
#  ('Miaoshou Doctor', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2019', 2015, 4, '3 to 5'),
#  ('Poizon', 'Asia', 'China', 'Mobile & telecommunications', '2019', 2015, 4, '3 to 5'),
#  ('CoinTracker', 'North America', 'United States', 'Fintech', '2022', 2017, 5, '3 to 5'),
#  ('Manner', 'Asia', 'China', 'Other', '2020', 2015, 5, '3 to 5'),
#  ('Mamaearth', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2021', 2016, 5, '3 to 5'),
#  ('Black Sesame Technologies', 'Asia', 'China', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('Vise', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Printful', 'North America', 'United States', 'Other', '2021', 2016, 5, '3 to 5'),
#  ('Hasura', 'Asia', 'India', 'Internet software & services', '2022', 2017, 5, '3 to 5'),
#  ('Luoji Siwei', 'Asia', 'China', 'Edtech', '2017', 2012, 5, '3 to 5'),
#  ('Tackle.io', 'North America', 'United States', 'Internet software & services', '2021', 2016, 5, '3 to 5'),
#  ('Axiom Space', 'North America', 'United States', 'Other', '2021', 2016, 5, '3 to 5'),
#  ('Cresta', 'North America', 'United States', 'Artificial intelligence', '2022', 2017, 5, '3 to 5'),
#  ('Einride', 'Europe', 'Sweden', 'Auto & transportation', '2021', 2016, 5, '3 to 5'),
#  ('UISEE Technology', 'Asia', 'China', '"Supply chain, logistics, & delivery"', '2021', 2016, 5, '3 to 5'),
#  ('Qualia', 'North America', 'United States', 'Fintech', '2020', 2015, 5, '3 to 5'),
#  ('Pilot.com', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Cameo', 'North America', 'United States', 'Internet software & services', '2021', 2016, 5, '3 to 5'),
#  ('TUNGEE', 'Asia', 'China', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('Intellifusion', 'Asia', 'China', 'Artificial intelligence', '2019', 2014, 5, '3 to 5'),
#  ('Inxeption', 'North America', 'United States', 'Fintech', '2022', 2017, 5, '3 to 5'),
#  ('Amperity', 'North America', 'United States', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('DailyPay', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('SeekOut', 'North America', 'United States', 'Internet software & services', '2022', 2017, 5, '3 to 5'),
#  ('Ada Support', 'North America', 'Canada', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('Harness', 'North America', 'United States', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('Snyk', 'North America', 'United States', 'Cybersecurity', '2020', 2015, 5, '3 to 5'),
#  ('Airtable', 'North America', 'United States', 'Internet software & services', '2018', 2013, 5, '3 to 5'),
#  ('Cars24', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2020', 2015, 5, '3 to 5'),
#  ('Bolt', 'Europe', 'Estonia', 'Auto & transportation', '2018', 2013, 5, '3 to 5'),
#  ('Traveloka', 'Asia', 'Indonesia', 'Travel', '2017', 2012, 5, '3 to 5'),
#  ('WeDoctor', 'Asia', 'China', 'Health', '2015', 2010, 5, '3 to 5'),
#  ('SouChe Holdings', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2017', 2012, 5, '3 to 5'),
#  ('Orbbec Technology', 'Asia', 'China', 'Hardware', '2018', 2013, 5, '3 to 5'),
#  ('Tripledot', 'Europe', 'United Kingdom', 'Mobile & telecommunications', '2022', 2017, 5, '3 to 5'),
#  ('Zego', 'Europe', 'United Kingdom', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Loom', 'North America', 'United States', 'Internet software & services', '2021', 2016, 5, '3 to 5'),
#  ('Sunbit', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Aiven', 'Europe', 'Finland', 'Internet software & services', '2021', 2016, 5, '3 to 5'),
#  ('Flipboard', 'North America', 'United States', 'Internet software & services', '2015', 2010, 5, '3 to 5'),
#  ('dMed Biopharmaceutical', 'Asia', 'China', 'Health', '2021', 2016, 5, '3 to 5'),
#  ('Cognite', 'Europe', 'Norway', 'Data management & analytics', '2021', 2016, 5, '3 to 5'),
#  ('CredAvenue', 'Asia', 'India', 'Fintech', '2022', 2017, 5, '3 to 5'),
#  ('WeBull', 'Asia', 'China', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Everly Health', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2020', 2015, 5, '3 to 5'),
#  ('TensTorrent', 'North America', 'Canada', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('Opentrons', 'North America', 'United States', 'Hardware', '2021', 2016, 5, '3 to 5'),
#  ('Papa', 'North America', 'United States', 'Health', '2021', 2016, 5, '3 to 5'),
#  ('Lusha', 'North America', 'United States', 'Internet software & services', '2021', 2016, 5, '3 to 5'),
#  ('BigID', 'North America', 'United States', 'Cybersecurity', '2020', 2015, 5, '3 to 5'),
#  ('Rivigo', 'Asia', 'India', '"Supply chain, logistics, & delivery"', '2019', 2014, 5, '3 to 5'),
#  ('Hyperchain', 'Asia', 'China', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Mobvoi', 'Asia', 'China', 'Consumer & retail', '2017', 2012, 5, '3 to 5'),
#  ('Paradox', 'North America', 'United States', 'Internet software & services', '2021', 2016, 5, '3 to 5'),
#  ('Owkin', 'North America', 'United States', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('Truepill', 'North America', 'United States', 'Health', '2021', 2016, 5, '3 to 5'),
#  ('Expel', 'North America', 'United States', 'Cybersecurity', '2021', 2016, 5, '3 to 5'),
#  ('HyalRoute', 'Asia', 'Singapore', 'Mobile & telecommunications', '2020', 2015, 5, '3 to 5'),
#  ('Glossier', 'North America', 'United States', 'Consumer & retail', '2019', 2014, 5, '3 to 5'),
#  ('K Health', 'North America', 'United States', 'Health', '2021', 2016, 5, '3 to 5'),
#  ('TrueLayer', 'Europe', 'United Kingdom', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Infra.Market', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2021', 2016, 5, '3 to 5'),
#  ('Emerging Markets Property Group', 'Asia', 'United Arab Emirates', 'Other', '2020', 2015, 5, '3 to 5'),
#  ('Capitolis', 'North America', 'United States', 'Fintech', '2022', 2017, 5, '3 to 5'),
#  ('YugaByte', 'North America', 'United States', 'Data management & analytics', '2021', 2016, 5, '3 to 5'),
#  ('At-Bay', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Rec Room', 'North America', 'United States', 'Internet software & services', '2021', 2016, 5, '3 to 5'),
#  ('fabric', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2022', 2017, 5, '3 to 5'),
#  ('Spring Health', 'North America', 'United States', 'Health', '2021', 2016, 5, '3 to 5'),
#  ('Veho', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2021', 2016, 5, '3 to 5'),
#  ('Flexport', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2018', 2013, 5, '3 to 5'),
#  ('Clearcover', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Moveworks', 'North America', 'United States', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('KnowBox', 'Asia', 'China', 'Edtech', '2019', 2014, 5, '3 to 5'),
#  ('WTOIP', 'Asia', 'China', 'Internet software & services', '2018', 2013, 5, '3 to 5'),
#  ('Swile', 'Europe', 'France', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Cedar', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Inari', 'North America', 'United States', 'Other', '2021', 2016, 5, '3 to 5'),
#  ('Dragos', 'North America', 'United States', 'Cybersecurity', '2021', 2016, 5, '3 to 5'),
#  ('TangoMe', 'North America', 'United States', 'Mobile & telecommunications', '2014', 2009, 5, '3 to 5'),
#  ('Groq', 'North America', 'United States', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('Alan', 'Europe', 'France', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Virta Health', 'North America', 'United States', 'Health', '2020', 2015, 5, '3 to 5'),
#  ('Zhaogang', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2017', 2012, 5, '3 to 5'),
#  ('TELD', 'Asia', 'China', 'Fintech', '2019', 2014, 5, '3 to 5'),
#  ('Omio', 'Europe', 'Germany', 'Travel', '2018', 2013, 5, '3 to 5'),
#  ('BlockDaemon', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('solarisBank', 'Europe', 'Germany', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Ethos', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('dbt Labs', 'North America', 'United States', 'Data management & analytics', '2021', 2016, 5, '3 to 5'),
#  ('Pagaya', 'Asia', 'Israel', 'Fintech', '2020', 2015, 5, '3 to 5'),
#  ('VerbIT', 'North America', 'United States', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('Solugen', 'North America', 'United States', 'Other', '2021', 2016, 5, '3 to 5'),
#  ('Papaya Global', 'North America', 'United States', 'Internet software & services', '2021', 2016, 5, '3 to 5'),
#  ('Acko General Insurance', 'Asia', 'India', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Flutterwave', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('ApplyBoard', 'North America', 'Canada', 'Edtech', '2020', 2015, 5, '3 to 5'),
#  ('Zipline', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2019', 2014, 5, '3 to 5'),
#  ("Rothy's", 'North America', 'United States', 'Consumer & retail', '2021', 2016, 5, '3 to 5'),
#  ('GOAT', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2020', 2015, 5, '3 to 5'),
#  ('Remote', 'North America', 'United States', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Yuanfudao', 'Asia', 'China', 'Edtech', '2017', 2012, 5, '3 to 5'),
#  ('PandaDoc', 'North America', 'United States', 'Internet software & services', '2021', 2016, 5, '3 to 5'),
#  ('Alto Pharmacy', 'North America', 'United States', 'Health', '2020', 2015, 5, '3 to 5'),
#  ('BlueVoyant', 'North America', 'United States', 'Cybersecurity', '2022', 2017, 5, '3 to 5'),
#  ('Digit Insurance', 'Asia', 'India', 'Fintech', '2021', 2016, 5, '3 to 5'),
#  ('Cato Networks', 'Asia', 'Israel', 'Cybersecurity', '2020', 2015, 5, '3 to 5'),
#  ('Advance Intelligence Group', 'Asia', 'Singapore', 'Artificial intelligence', '2021', 2016, 5, '3 to 5'),
#  ('DianRong', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2017', 2012, 5, '3 to 5'),
#  ('Checkr', 'North America', 'United States', 'Internet software & services', '2019', 2014, 5, '3 to 5'),
#  ('Capsule', 'North America', 'United States', 'Health', '2021', 2016, 5, '3 to 5'),
#  ('XiaoZhu', 'Asia', 'China', 'Travel', '2017', 2012, 5, '3 to 5'),
#  ('Gong', 'North America', 'United States', 'Artificial intelligence', '2020', 2015, 5, '3 to 5'),
#  ('Forto', 'Europe', 'Germany', '"Supply chain, logistics, & delivery"', '2021', 2016, 5, '3 to 5'),
#  ('KK Group', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2019', 2014, 5, '3 to 5'),
#  ('Cohesity', 'North America', 'United States', 'Data management & analytics', '2018', 2013, 5, '3 to 5'),
#  ('CureFit', 'Asia', 'India', 'Health', '2021', 2016, 5, '3 to 5'),
#  ('PsiQuantum', 'North America', 'United States', 'Hardware', '2021', 2016, 5, '3 to 5'),
#  ('Circle', 'North America', 'United States', 'Fintech', '2018', 2013, 5, '3 to 5'),
#  ('Ximalaya FM', 'Asia', 'China', 'Mobile & telecommunications', '2017', 2012, 5, '3 to 5'),
#  ('Workrise', 'North America', 'United States', 'Internet software & services', '2019', 2014, 5, '3 to 5'),
#  ('Improbable', 'Europe', 'United Kingdom', 'Other', '2017', 2012, 5, '3 to 5'),
#  ('Mininglamp Technology', 'Asia', 'China', 'Artificial intelligence', '2019', 2014, 5, '3 to 5'),
#  ('Unacademy', 'Asia', 'India', 'Edtech', '2020', 2015, 5, '3 to 5'),
#  ("Harry's", 'North America', 'United States', 'Consumer & retail', '2018', 2013, 5, '3 to 5'),
#  ('Toss', 'Asia', 'South Korea', 'Fintech', '2018', 2013, 5, '3 to 5'),
#  ('Bytedance', 'Asia', 'China', 'Artificial intelligence', '2017', 2012, 5, '3 to 5'),
#  ('Lyra Health', 'North America', 'United States', 'Health', '2020', 2015, 5, '3 to 5'),
#  ('wefox', 'Europe', 'Germany', 'Fintech', '2019', 2014, 5, '3 to 5'),
#  ('Xingyun Group', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2020', 2015, 5, '3 to 5'),
#  ('CMR Surgical', 'Europe', 'United Kingdom', 'Health', '2019', 2014, 5, '3 to 5'),
#  ('Moka', 'Asia', 'China', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('Quantum Metric', 'North America', 'United States', 'Data management & analytics', '2021', 2015, 6, '6 to 10'),
#  ('Xiaoe Tech', 'Asia', 'China', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('Athelas', 'North America', 'United States', 'Health', '2022', 2016, 6, '6 to 10'),
#  ('Tezign', 'Asia', 'China', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('News Break', 'North America', 'United States', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('Alloy', 'North America', 'United States', 'Fintech', '2021', 2015, 6, '6 to 10'),
#  ('Placer.ai', 'North America', 'United States', 'Artificial intelligence', '2022', 2016, 6, '6 to 10'),
#  ('LinkTree', 'Oceania', 'Australia', 'Internet software & services', '2022', 2016, 6, '6 to 10'),
#  ('Mux', 'North America', 'United States', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('Iluvatar CoreX', 'Asia', 'China', 'Hardware', '2021', 2015, 6, '6 to 10'),
#  ('Valgen Medtech', 'Asia', 'China', 'Health', '2021', 2015, 6, '6 to 10'),
#  ('UpGrad', 'Asia', 'India', 'Edtech', '2021', 2015, 6, '6 to 10'),
#  ('MEGVII', 'Asia', 'China', 'Artificial intelligence', '2017', 2011, 6, '6 to 10'),
#  ('Netskope', 'North America', 'United States', 'Cybersecurity', '2018', 2012, 6, '6 to 10'),
#  ('ServiceTitan', 'North America', 'United States', 'Internet software & services', '2018', 2012, 6, '6 to 10'),
#  ('Digital Currency Group', 'North America', 'United States', 'Fintech', '2021', 2015, 6, '6 to 10'),
#  ('FlixBus', 'Europe', 'Germany', 'Auto & transportation', '2019', 2013, 6, '6 to 10'),
#  ('Meesho', 'Asia', 'India', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('ShareChat', 'Asia', 'India', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('Radiology Partners', 'North America', 'United States', 'Health', '2018', 2012, 6, '6 to 10'),
#  ('XForcePlus', 'Asia', 'China', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('STORD', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2021', 2015, 6, '6 to 10'),
#  ('YunQuNa', 'Asia', 'China', '"Supply chain, logistics, & delivery"', '2021', 2015, 6, '6 to 10'),
#  ('Electric', 'North America', 'United States', 'Cybersecurity', '2022', 2016, 6, '6 to 10'),
#  ('Huisuanzhang', 'Asia', 'China', 'Fintech', '2021', 2015, 6, '6 to 10'),
#  ('Outschool', 'North America', 'United States', 'Edtech', '2021', 2015, 6, '6 to 10'),
#  ('Boom Supersonic', 'North America', 'United States', 'Other', '2020', 2014, 6, '6 to 10'),
#  ('Slice', 'Asia', 'India', 'Fintech', '2021', 2015, 6, '6 to 10'),
#  ('Jiuxian', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2015', 2009, 6, '6 to 10'),
#  ('Tongdun Technology', 'Asia', 'China', 'Cybersecurity', '2019', 2013, 6, '6 to 10'),
#  ('Incode Technologies', 'North America', 'United States', 'Cybersecurity', '2021', 2015, 6, '6 to 10'),
#  ('LetsGetChecked', 'Europe', 'Ireland', 'Health', '2021', 2015, 6, '6 to 10'),
#  ('Aqua Security', 'Asia', 'Israel', 'Cybersecurity', '2021', 2015, 6, '6 to 10'),
#  ('Salt Security', 'North America', 'United States', 'Cybersecurity', '2022', 2016, 6, '6 to 10'),
#  ('Hibob', 'Asia', 'Israel', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('ZenBusiness', 'North America', 'United States', 'Fintech', '2021', 2015, 6, '6 to 10'),
#  ('Lookout', 'North America', 'United States', 'Cybersecurity', '2013', 2007, 6, '6 to 10'),
#  ('GO1', 'Oceania', 'Australia', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('Built', 'North America', 'United States', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('Fabric', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2021', 2015, 6, '6 to 10'),
#  ('SWORD Health', 'North America', 'United States', 'Health', '2021', 2015, 6, '6 to 10'),
#  ('Articulate', 'North America', 'United States', 'Edtech', '2021', 2015, 6, '6 to 10'),
#  ('Chime', 'North America', 'United States', 'Fintech', '2019', 2013, 6, '6 to 10'),
#  ('Getir', 'Europe', 'Turkey', 'E-commerce & direct-to-consumer', '2021', 2015, 6, '6 to 10'),
#  ('Snapdeal', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2014', 2008, 6, '6 to 10'),
#  ('Lalamove', 'Asia', 'Hong Kong', '"Supply chain, logistics, & delivery"', '2019', 2013, 6, '6 to 10'),
#  ('Lacework', 'North America', 'United States', 'Cybersecurity', '2021', 2015, 6, '6 to 10'),
#  ('N26', 'Europe', 'Germany', 'Fintech', '2019', 2013, 6, '6 to 10'),
#  ('Astranis Space Technologies', 'North America', 'United States', 'Mobile & telecommunications', '2021', 2015, 6, '6 to 10'),
#  ('Lightricks', 'Asia', 'Israel', 'Artificial intelligence', '2019', 2013, 6, '6 to 10'),
#  ('MyGlamm', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2021', 2015, 6, '6 to 10'),
#  ('Vercel', 'North America', 'United States', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
#  ('Komodo Health', 'North America', 'United States', 'Health', '2020', 2014, 6, '6 to 10'),
#  ('Olist', 'South America', 'Brazil', 'E-commerce & direct-to-consumer', '2021', 2015, 6, '6 to 10'),
#  ('M1 Finance', 'North America', 'United States', 'Fintech', '2021', 2015, 6, '6 to 10'),
#  ('DriveNets', 'Asia', 'Israel', 'Internet software & services', '2021', 2015, 6, '6 to 10'),
# ...
#  ('Bought By Many', 'Europe', 'United Kingdom', 'Fintech', '2021', 2012, 9, '6 to 10'),
#  ('Rokt', 'North America', 'United States', 'Internet software & services', '2021', 2012, 9, '6 to 10'),
#  ('Clari', 'North America', 'United States', 'Internet software & services', '2021', 2012, 9, '6 to 10'),
#  ("BYJU's", 'Asia', 'India', 'Edtech', '2017', 2008, 9, '6 to 10'),
#  ('Age of Learning', 'North America', 'United States', 'Edtech', '2016', 2007, 9, '6 to 10'),
#  ('Mafengwo', 'Asia', 'China', 'Travel', '2019', 2010, 9, '6 to 10'),
#  ('Paxos', 'North America', 'United States', 'Fintech', '2021', 2012, 9, '6 to 10'),
#  ('DriveWealth', 'North America', 'United States', 'Fintech', '2021', 2012, 9, '6 to 10'),
#  ('Socure', 'North America', 'United States', 'Cybersecurity', '2021', 2012, 9, '6 to 10'),
#  ('Dunamu', 'Asia', 'South Korea', 'Fintech', '2021', 2012, 9, '6 to 10'),
#  ('ContentSquare', 'Europe', 'France', 'Internet software & services', '2021', 2012, 9, '6 to 10'),
#  ('Tradeshift', 'North America', 'United States', 'Fintech', '2018', 2009, 9, '6 to 10'),
#  ('Mirakl', 'Europe', 'France', 'E-commerce & direct-to-consumer', '2020', 2011, 9, '6 to 10'),
#  ('Carson Group', 'North America', 'United States', 'Fintech', '2021', 2012, 9, '6 to 10'),
#  ('Pet Circle', 'Oceania', 'Australia', 'E-commerce & direct-to-consumer', '2021', 2011, 10, '6 to 10'),
#  ('Sentry', 'North America', 'United States', 'Other', '2021', 2011, 10, '6 to 10'),
#  ('Domestika', 'North America', 'United States', 'Internet software & services', '2022', 2012, 10, '6 to 10'),
#  ('Glia', 'North America', 'United States', 'Fintech', '2022', 2012, 10, '6 to 10'),
#  ('Dadi Cinema', 'Asia', 'China', 'Other', '2016', 2006, 10, '6 to 10'),
#  ('Sift', 'North America', 'United States', 'Artificial intelligence', '2021', 2011, 10, '6 to 10'),
#  ('Phenom People', 'North America', 'United States', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('Qingting FM', 'Asia', 'China', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('LEAD School', 'Asia', 'India', 'Edtech', '2022', 2012, 10, '6 to 10'),
#  ('Insider', 'Europe', 'Turkey', 'Internet software & services', '2022', 2012, 10, '6 to 10'),
#  ('StoreDot', 'Asia', 'Israel', 'Other', '2022', 2012, 10, '6 to 10'),
#  ('MURAL', 'North America', 'United States', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('PicsArt', 'North America', 'United States', 'Mobile & telecommunications', '2021', 2011, 10, '6 to 10'),
#  ('CommerceIQ', 'North America', 'United States', 'Artificial intelligence', '2022', 2012, 10, '6 to 10'),
#  ('Zapier', 'North America', 'United States', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('A24 Films', 'North America', 'United States', 'Other', '2022', 2012, 10, '6 to 10'),
#  ('BrewDog', 'Europe', 'United Kingdom', 'Consumer & retail', '2017', 2007, 10, '6 to 10'),
#  ('Reltio', 'North America', 'United States', 'Data management & analytics', '2021', 2011, 10, '6 to 10'),
#  ('BrowserStack', 'Europe', 'Ireland', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('H2O.ai', 'North America', 'United States', 'Artificial intelligence', '2021', 2011, 10, '6 to 10'),
#  ('Culture Amp', 'Oceania', 'Australia', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('Lydia', 'Europe', 'France', 'Fintech', '2021', 2011, 10, '6 to 10'),
#  ('Skydance Media', 'North America', 'United States', 'Other', '2020', 2010, 10, '6 to 10'),
#  ('Augury', 'North America', 'United States', 'Artificial intelligence', '2021', 2011, 10, '6 to 10'),
#  ('Everlaw', 'North America', 'United States', 'Internet software & services', '2020', 2010, 10, '6 to 10'),
#  ('Fever Labs', 'North America', 'United States', 'Internet software & services', '2022', 2012, 10, '6 to 10'),
#  ('SHEIN', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2018', 2008, 10, '6 to 10'),
#  ('Matillion', 'Europe', 'United Kingdom', 'Data management & analytics', '2021', 2011, 10, '6 to 10'),
#  ('CircleCI', 'North America', 'United States', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('LTK', 'North America', 'United States', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('BigPanda', 'North America', 'United States', 'Artificial intelligence', '2022', 2012, 10, '6 to 10'),
#  ('OVO Energy', 'Europe', 'United Kingdom', 'Other', '2019', 2009, 10, '6 to 10'),
#  ('Zenoti', 'North America', 'United States', 'Internet software & services', '2020', 2010, 10, '6 to 10'),
#  ('TradingView', 'North America', 'United States', 'Fintech', '2021', 2011, 10, '6 to 10'),
#  ('Globalization Partners', 'North America', 'United States', 'Internet software & services', '2022', 2012, 10, '6 to 10'),
#  ('Vectra Networks', 'North America', 'United States', 'Artificial intelligence', '2021', 2011, 10, '6 to 10'),
#  ('Icertis', 'North America', 'United States', 'Artificial intelligence', '2019', 2009, 10, '6 to 10'),
#  ('Devo', 'North America', 'United States', 'Data management & analytics', '2021', 2011, 10, '6 to 10'),
#  ('GupShup', 'North America', 'United States', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('Yunxuetang', 'Asia', 'China', 'Edtech', '2021', 2011, 10, '6 to 10'),
#  ('Signifyd', 'North America', 'United States', 'Fintech', '2021', 2011, 10, '6 to 10'),
#  ('Grammarly', 'North America', 'United States', 'Internet software & services', '2019', 2009, 10, '6 to 10'),
#  ('Pharmapacks', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2020', 2010, 10, '6 to 10'),
#  ('Yotpo', 'North America', 'United States', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('FirstCry', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2020', 2010, 10, '6 to 10'),
#  ('Mambu', 'Europe', 'Netherlands', 'Fintech', '2021', 2011, 10, '6 to 10'),
#  ('ChargeBee Technologies', 'North America', 'United States', 'Fintech', '2021', 2011, 10, '6 to 10'),
#  ('Trulioo', 'North America', 'Canada', 'Cybersecurity', '2021', 2011, 10, '6 to 10'),
#  ('Blockchain.com', 'Europe', 'United Kingdom', 'Fintech', '2021', 2011, 10, '6 to 10'),
#  ('Fanatics', 'North America', 'United States', 'E-commerce & direct-to-consumer', '2012', 2002, 10, '6 to 10'),
#  ('Acorns', 'North America', 'United States', 'Fintech', '2022', 2012, 10, '6 to 10'),
#  ('ONE', 'Asia', 'Singapore', 'Internet software & services', '2021', 2011, 10, '6 to 10'),
#  ('Rebel Foods', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2021', 2011, 10, '6 to 10'),
#  ('Tipalti', 'North America', 'United States', 'Fintech', '2020', 2010, 10, '6 to 10'),
#  ('HeartFlow', 'North America', 'United States', 'Health', '2017', 2007, 10, '6 to 10'),
#  ('Xpressbees', 'Asia', 'India', '"Supply chain, logistics, & delivery"', '2022', 2012, 10, '6 to 10'),
#  ('Nuvemshop', 'South America', 'Brazil', 'E-commerce & direct-to-consumer', '2021', 2011, 10, '6 to 10'),
#  ('GetYourGuide', 'Europe', 'Germany', 'Travel', '2019', 2009, 10, '6 to 10'),
#  ('Biosplice Therapeutics', 'North America', 'United States', 'Health', '2018', 2008, 10, '6 to 10'),
#  ('SpaceX', 'North America', 'United States', 'Other', '2012', 2002, 10, '6 to 10'),
#  ('JoyTunes', 'Asia', 'Israel', 'Edtech', '2021', 2011, 10, '6 to 10'),
#  ('JOLLY Information Technology', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2018', 2008, 10, '6 to 10'),
#  ('Cloudinary', 'North America', 'United States', 'Internet software & services', '2022', 2011, 11, '11 to 25'),
#  ('Afiniti', 'North America', 'Bermuda', 'Artificial intelligence', '2017', 2006, 11, '11 to 25'),
#  ('ID.me', 'North America', 'United States', 'Cybersecurity', '2021', 2010, 11, '11 to 25'),
#  ('Strava', 'North America', 'United States', 'Internet software & services', '2020', 2009, 11, '11 to 25'),
#  ('Lucid', 'North America', 'United States', 'Internet software & services', '2021', 2010, 11, '11 to 25'),
#  ('Pantheon Systems', 'North America', 'United States', 'Internet software & services', '2021', 2010, 11, '11 to 25'),
#  ('Visier', 'North America', 'Canada', 'Internet software & services', '2021', 2010, 11, '11 to 25'),
#  ('SmartRecruiters', 'North America', 'United States', 'Internet software & services', '2021', 2010, 11, '11 to 25'),
#  ('Keenon Robotics', 'Asia', 'China', '"Supply chain, logistics, & delivery"', '2021', 2010, 11, '11 to 25'),
#  ('CloudBees', 'North America', 'United States', 'Data management & analytics', '2021', 2010, 11, '11 to 25'),
#  ('FLASH', 'North America', 'United States', 'Fintech', '2022', 2011, 11, '11 to 25'),
#  ('MediaMath', 'North America', 'United States', 'Internet software & services', '2018', 2007, 11, '11 to 25'),
#  ('Betterment', 'North America', 'United States', 'Fintech', '2021', 2010, 11, '11 to 25'),
#  ('o9 Solutions', 'North America', 'United States', 'Artificial intelligence', '2020', 2009, 11, '11 to 25'),
#  ('Omada Health', 'North America', 'United States', 'Health', '2022', 2011, 11, '11 to 25'),
#  ('MX Technologies', 'North America', 'United States', 'Fintech', '2021', 2010, 11, '11 to 25'),
#  ('Miro', 'North America', 'United States', 'Internet software & services', '2022', 2011, 11, '11 to 25'),
#  ('GoCardless', 'Europe', 'United Kingdom', 'Fintech', '2022', 2011, 11, '11 to 25'),
#  ('Deezer', 'Europe', 'France', 'Internet software & services', '2018', 2007, 11, '11 to 25'),
#  ('C2FO', 'North America', 'United States', 'Fintech', '2019', 2008, 11, '11 to 25'),
#  ('PAX', 'North America', 'United States', 'Consumer & retail', '2018', 2007, 11, '11 to 25'),
#  ('Upstox', 'Asia', 'India', 'Fintech', '2021', 2010, 11, '11 to 25'),
#  ('Kajabi', 'North America', 'United States', 'Internet software & services', '2021', 2010, 11, '11 to 25'),
#  ('Vinted', 'Europe', 'Lithuania', 'E-commerce & direct-to-consumer', '2019', 2008, 11, '11 to 25'),
#  ('Eruditus Executive Education', 'Asia', 'India', 'Edtech', '2021', 2010, 11, '11 to 25'),
#  ('Collibra', 'Europe', 'Belgium', 'Data management & analytics', '2019', 2008, 11, '11 to 25'),
#  ('Volocopter', 'Europe', 'Germany', 'Auto & transportation', '2022', 2011, 11, '11 to 25'),
#  ('Xingsheng Selected', 'Asia', 'China', 'E-commerce & direct-to-consumer', '2020', 2009, 11, '11 to 25'),
#  ('PolicyBazaar', 'Asia', 'India', 'Fintech', '2019', 2008, 11, '11 to 25'),
#  ('ZEPZ', 'Europe', 'United Kingdom', 'Fintech', '2021', 2010, 11, '11 to 25'),
#  ('Cava Group', 'North America', 'United States', 'Other', '2021', 2010, 11, '11 to 25'),
#  ('Xinchao Media', 'Asia', 'China', 'Internet software & services', '2018', 2007, 11, '11 to 25'),
#  ('Lenskart', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2019', 2008, 11, '11 to 25'),
#  ('Yiguo', 'Asia', 'China', '"Supply chain, logistics, & delivery"', '2016', 2005, 11, '11 to 25'),
#  ('Meizu Technology', 'Asia', 'China', 'Hardware', '2014', 2003, 11, '11 to 25'),
#  ('Iodine Software', 'North America', 'United States', 'Data management & analytics', '2021', 2010, 11, '11 to 25'),
#  ('Athletic Greens', 'North America', 'United States', 'Health', '2022', 2010, 12, '11 to 25'),
#  ('Vagaro', 'North America', 'United States', 'Internet software & services', '2021', 2009, 12, '11 to 25'),
#  ('reddit', 'North America', 'United States', 'Internet software & services', '2017', 2005, 12, '11 to 25'),
#  ('Axtria', 'North America', 'United States', 'Data management & analytics', '2021', 2009, 12, '11 to 25'),
#  ('Coocaa', 'Asia', 'China', 'Hardware', '2018', 2006, 12, '11 to 25'),
#  ('MobiKwik', 'Asia', 'India', 'Fintech', '2021', 2009, 12, '11 to 25'),
#  ('Feedzai', 'North America', 'United States', 'Artificial intelligence', '2021', 2009, 12, '11 to 25'),
#  ('Mixpanel', 'North America', 'United States', 'Internet software & services', '2021', 2009, 12, '11 to 25'),
#  ('Dream11', 'Asia', 'India', 'Internet software & services', '2019', 2007, 12, '11 to 25'),
#  ('MadeiraMadeira', 'South America', 'Brazil', 'E-commerce & direct-to-consumer', '2021', 2009, 12, '11 to 25'),
#  ('ezCater', 'North America', 'United States', '"Supply chain, logistics, & delivery"', '2019', 2007, 12, '11 to 25'),
#  ('Druva', 'North America', 'United States', 'Data management & analytics', '2019', 2007, 12, '11 to 25'),
#  ('Epidemic Sound', 'Europe', 'Sweden', 'Internet software & services', '2021', 2009, 12, '11 to 25'),
#  ('Assent', 'North America', 'Canada', '"Supply chain, logistics, & delivery"', '2022', 2010, 12, '11 to 25'),
#  ('Vestiaire Collective', 'Europe', 'France', 'E-commerce & direct-to-consumer', '2021', 2009, 12, '11 to 25'),
#  ('Addepar', 'North America', 'United States', 'Fintech', '2021', 2009, 12, '11 to 25'),
#  ('Jobandtalent', 'Europe', 'Spain', 'Internet software & services', '2021', 2009, 12, '11 to 25'),
#  ('Kong', 'North America', 'United States', 'Internet software & services', '2020', 2007, 13, '11 to 25'),
#  ('Happy Money', 'North America', 'United States', 'Fintech', '2022', 2009, 13, '11 to 25'),
#  ('Chipone', 'Asia', 'China', 'Hardware', '2021', 2008, 13, '11 to 25'),
#  ('Trendy Group International', 'Asia', 'Hong Kong', 'Consumer & retail', '2012', 1999, 13, '11 to 25'),
#  ('Nextiva', 'North America', 'United States', 'Internet software & services', '2021', 2008, 13, '11 to 25'),
#  ('SoundHound', 'North America', 'United States', 'Artificial intelligence', '2018', 2005, 13, '11 to 25'),
#  ('SMS Assist', 'North America', 'United States', 'Internet software & services', '2016', 2003, 13, '11 to 25'),
#  ('impact.com', 'North America', 'United States', 'Internet software & services', '2021', 2008, 13, '11 to 25'),
#  ('Tealium', 'North America', 'United States', 'Internet software & services', '2021', 2008, 13, '11 to 25'),
#  ('Scandit', 'Europe', 'Switzerland', '"Supply chain, logistics, & delivery"', '2022', 2009, 13, '11 to 25'),
#  ('Public', 'North America', 'United States', 'Fintech', '2021', 2008, 13, '11 to 25'),
#  ('Tarana Wireless', 'North America', 'United States', 'Mobile & telecommunications', '2022', 2009, 13, '11 to 25'),
#  ('Clio', 'North America', 'Canada', 'Internet software & services', '2021', 2008, 13, '11 to 25'),
#  ('CAIS', 'North America', 'United States', 'Fintech', '2022', 2009, 13, '11 to 25'),
#  ('Vista Global', 'Asia', 'United Arab Emirates', 'Other', '2017', 2004, 13, '11 to 25'),
#  ('BloomReach', 'North America', 'United States', 'Artificial intelligence', '2022', 2009, 13, '11 to 25'),
#  ('CarDekho', 'Asia', 'India', 'E-commerce & direct-to-consumer', '2021', 2008, 13, '11 to 25'),
#  ('YipitData', 'North America', 'United States', 'Internet software & services', '2021', 2008, 13, '11 to 25'),
#  ('DailyHunt', 'Asia', 'India', 'Internet software & services', '2020', 2007, 13, '11 to 25'),
#  ('RIDI', 'Asia', 'South Korea', 'E-commerce & direct-to-consumer', '2022', 2008, 14, '11 to 25'),
#  ('Infobip', 'Europe', 'Croatia', 'Mobile & telecommunications', '2020', 2006, 14, '11 to 25'),
#  ('HuJiang', 'Asia', 'China', 'Edtech', '2015', 2001, 14, '11 to 25'),
#  ('Unico', 'South America', 'Brazil', 'Artificial intelligence', '2021', 2007, 14, '11 to 25'),
#  ('Amagi', 'Asia', 'India', 'Internet software & services', '2022', 2008, 14, '11 to 25'),
#  ('Gelato', 'Europe', 'Norway', 'E-commerce & direct-to-consumer', '2021', 2007, 14, '11 to 25'),
#  ('Huaqin Telecom Technology', 'Asia', 'China', 'Mobile & telecommunications', '2019', 2005, 14, '11 to 25'),
#  ('Yanolja', 'Asia', 'South Korea', 'Travel', '2019', 2005, 14, '11 to 25'),
#  ('Rad Power Bikes', 'North America', 'United States', 'Auto & transportation', '2021', 2007, 14, '11 to 25'),
#  ('ReliaQuest', 'North America', 'United States', 'Cybersecurity', '2021', 2007, 14, '11 to 25'),
#  ('PatSnap', 'Asia', 'Singapore', 'Internet software & services', '2021', 2007, 14, '11 to 25'),
#  ('Neo4j', 'North America', 'United States', 'Data management & analytics', '2021', 2007, 14, '11 to 25'),
#  ('HighRadius', 'North America', 'United States', 'Fintech', '2020', 2006, 14, '11 to 25'),
#  ('Course Hero', 'North America', 'United States', 'Edtech', '2020', 2006, 14, '11 to 25'),
#  ('Spiber', 'Asia', 'Japan', 'Other', '2021', 2007, 14, '11 to 25'),
#  ...]

# %% [markdown]
# ### Make the result as a table

# %%
# %%sql
# CREATE VIEW year_window AS
#
# SELECT
# c.company,
# c.continent,
# c.country,
# i.industry,
# strftime('%Y',d.date_joined) AS year_joined,
# d.year_founded,
# CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) AS years_to_be_unicorn,
#     CASE WHEN
#               CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 2 THEN '0 to 2'
#         WHEN CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 5  AND
#              CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) > 2 THEN '3 to 5'
#         WHEN CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 10  AND
#              CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) > 5  THEN '6 to 10'
#         WHEN CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 25  AND
#              CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) > 10  THEN '11 to 25'
#         ELSE '+ 25'
#         END AS year_window_to_be_unicorn
# FROM funding f
# JOIN companies c
# ON f.company_id=c.company_id
# join industries i
# ON i.company_id = c.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# ORDER BY 7
# Out:
#  * sqlite:///unicorn
# (sqlite3.OperationalError) table year_window already exists
# [SQL: CREATE VIEW year_window AS
#
# SELECT
# c.company,
# c.continent,
# c.country,
# i.industry,
# strftime('%Y',d.date_joined) AS year_joined,
# d.year_founded,
# CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) AS years_to_be_unicorn,
#     CASE WHEN
#               CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 2 THEN '0 to 2'
#         WHEN CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 5  AND
#              CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) > 2 THEN '3 to 5'
#         WHEN CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 10  AND
#              CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) > 5  THEN '6 to 10'
#         WHEN CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) <= 25  AND
#              CAST(strftime('%Y',d.date_joined) AS NUMERIC) - CAST((d.year_founded) AS NUMERIC) > 10  THEN '11 to 25'
#         ELSE '+ 25'
#         END AS year_window_to_be_unicorn
# FROM funding f
# JOIN companies c
# ON f.company_id=c.company_id
# join industries i
# ON i.company_id = c.company_id
# JOIN dates d
# ON d.company_id = c.company_id
# ORDER BY 7]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ### Now we can get summary of number of camanies in each bin group

# %%
# %%sql
# SELECT year_window_to_be_unicorn, COUNT(year_window_to_be_unicorn)
# FROM year_window
# GROUP BY 1
# order by 2
# Out:
#  * sqlite:///unicorn
# Done.
# [('+ 25', 7),
#  ('0 to 2', 114),
#  ('11 to 25', 154),
#  ('3 to 5', 352),
#  ('6 to 10', 447)]
